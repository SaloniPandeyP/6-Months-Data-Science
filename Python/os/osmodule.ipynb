# %% [markdown]
# # OS Module

# %%
print("h")
# Out:
# h

# %%
# os ,math,re
import os

# %%
os.getcwd()  #### get current working directrey
# Out:
# 'c:\\Users\\hp\\OneDrive\\ドキュメント\\Desktop\\Data science\\Python\\os'

# %%
os.listdir(r'c:\\Users\\hp\\OneDrive\\ドキュメント\\Desktop\\Data science\\Python\\os')
# Out:
# ['osmodule.ipynb']

# %%
path = r
os.listdir(path)

# %%
os.mkdir("shalu")

# %%
#multiple folder
# os.mkdir(r"sha\hii\kese")

# %%
# os.remove(r"shalu")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\hp\\OneDrive\\ドキュメント\\Desktop\\Data science\\Python\\os'

# %%
# os.chdir()

# %%
# os.rmdir(r"C:\Users\hp\OneDrive\ドキュメント\Desktop\Data science\Python\os\shalu")

# %%
# os.removedirs("path")

# %%
os.stat(r"C:\Users\hp\OneDrive\ドキュメント\Desktop\Data science\Python\os\shalu\hello.txt")
# Out:
# os.stat_result(st_mode=33206, st_ino=13510798882463833, st_dev=2193142145, st_nlink=1, st_uid=0, st_gid=0, st_size=16, st_atime=1779879586, st_mtime=1779879586, st_ctime=1779879576)

# %%
os.startfile(r"C:\Users\hp\OneDrive\ドキュメント\Desktop\Data science\Python\os\shalu\hello.txt") # kisi bhi folder ko oper kerta h ek dusre screen per

# %%
# os.rename(r"hello.txt","saloni.txt")

# %%
# os.rename(r"C:\Users\hp\OneDrive\ドキュメント\Desktop\Data science\Python\os\shalu\hello.txt","C:\Users\hp\OneDrive\ドキュメント\Desktop\Data science\Python\os\shalu")

# %%
os.path.isfile(r"C:\Users\hp\OneDrive\ドキュメント\Desktop\Data science\Python\os")
# Out:
# False

# %%
os.path.isdir(r"C:\Users\hp\OneDrive\ドキュメント\Desktop\Data science\Python\app.py") #
# Out:
# False

# %%
os.path.exists(r"C:\Users\hp\OneDrive\ドキュメント\Desktop\Data science\Python\app.py")  # check kerta h ki file exists h ki nhi
# Out:
# True

# %%
p1=r'"C:\Users\hp\OneDrive\ドキュメント\Desktop\html\html\react"'

# %%
path1= r'C:\Program Files (x86)'
path2= r'Windows Defender\en-GB'
Completepath = os.path.join(path1,path2)
# path
print(Completepath)
print(os.listdir(Completepath))
# Out:
# C:\Program Files (x86)\Windows Defender\en-GB
# ['EppManifest.dll.mui', 'MpAsDesc.dll.mui']

# %%
os.path.getsize(r"C:\Users\hp\OneDrive\ドキュメント\Desktop\Data science\Python\os\osmodule.ipynb")
# Out:
# 8273
