# %%
print("welcome file handling")
# Out:
# welcome file handling

# %%
#file=open("file_name","mode") # read mode
file=open('poit.txt','r')

# %%
# file.read()
# Out:
# 'hello saloni '

# %%
# file.readline()
# Out:
# ''

# %%
file.readlines()
# Out:
# ['alujhbnbnbmbm\n', 'pinkubvmnbmnbvcmbv']

# %%
#with ka mtlb h ki for loop ke sath work kerna
with open("poit.txt",'r') as file:
    print(file.read())
# Out:
# hello saloni bjnbkbkvjn
# shalujhbnbnbmbm
# pinkubvmnbmnbvcmbv

# %%
file.close()

# %%
#write mode

file = open("poit.txt",'w')
file.write("hello shalu how are you")
# Out:
# 23

# %%
file.close()

# %%
file = open("poit.txt",'r')
print(file.read())
# Out:
# hello shalu how are you

# %%
file.close() # disadvantage

# %%
file = open("saloni.txt",'w')
file.write("hello pinku")
# Out:
# 11

# %%
file.close()

# %%
file = open("saloni.txt",'r')
print(file.read())
# Out:
# hello pinku

# %%
file = open("poit.txt",'a')
file.write("hello kittu")
# Out:
# 11

# %%
file.close()

# %%
file = open("poit.txt",'r')
print(file.read())
# Out:
# hello shalu how are youhello kittu

# %%
file.close()

# %%
file = open("hey.txt",'a')
file.write("hello chiku")
# Out:
# 11

# %%
file.close()

# %%
file = open("hey.txt",'r')
print(file.read())
# Out:
# hello chiku

# %%
file = open("poit.txt",'x') ## x is show  the error
print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 file = open("poit.txt",'x')
#       2 print(file.read())
#
# FileExistsError: [Errno 17] File exists: 'poit.txt'

# %%
#### assignment 
# file record bnanana h bsf govt website ke liye jismai users se input lena h or uska pura details fill kerna h or ek new file or folder create kerna pdega
# file mai puri details aa jani chahiye user ki
# 1. create file se banni h usek bad users se input lene h

# %%
import os
First_name= input("Enter  your first name: ")
Last_name = input("Enter your last name: ")
Address= input("Enter your addresss: ")
Gender=input("Enter your Gender: ")
DOB = input("enter your DOB: ")

# create a folder
folder_name = First_name
if not os.path.exists(folder_name):
    os.mkdir(folder_name)



a=os.getcwd()
print("Current Path:", a)

file = open(f"{folder_name}/record.txt", "w")
file.write("----- User Record -----\n")
file.write(f"First Name : {First_name}\n")
file.write(f"Last Name  : {Last_name}\n")
file.write(f"Address    : {Address}\n")
file.write(f"Gender     : {Gender}\n")
file.write(f"DOB        : {DOB}\n")


file.close()

print("record successfully")
# Out:
# Current Path: c:\Users\hp\OneDrive\ドキュメント\Desktop\Data science\Python\os\filehandling
# record successfully
